# %% [markdown]
# ### Import all modules and libraries need.

# %%
# %matplotlib inline

import numpy as np
import scipy
import matplotlib.pyplot as plt

from scipy.io.wavfile import read
from scipy.signal import hann

# %% [markdown]
# ### Declare various functions needed for each step in the process.

# %%
def getwavedata(file):
    '''Imports sound data from a wav file via scipy and outputs a numpy.ndarray.'''
    # item 0 is the header info and item 1 is the audio data itself
    return scipy.io.wavfile.read(file)

# %%
# # setup a time scale for the x axis on plots that equates to the samaple counts of each file
# def timeScale(sound):
#     return np.arange(0, sound[1].shape[0]/float(sound[0]), (1.0/sound[0]), np.float32)

# # time = np.arange(0, 0.5, 1/float(rate)) # create a time spectrum from sound's rate
# time4khz = timeScale(sound4khz)

# %%
# function to take in data and file name and output simple plotted graph files
def makegraph(sound, timeRange, sample_rate, title=''):
    plt.figure()
    plt.plot(timeRange, sound)
    plt.ylabel("Amplitude")
    plt.xlabel("Time (seconds)")
    plt.title(title)
    plt.suptitle("Sampled at {}Hz".format(sample_rate))

# %%
def FFTwithHann(snd, rate):
    ''' Function will take in a numpy array from sound data 
        and output the frequency and power data as a tuple. '''
     # get shape from sound's numpy array
    shape = snd.shape[0]
    # create and apply the Hanning Window filter to audio data
    window = hann(shape)
    snd = snd * window
    # calculate the power and frequencies in audio sample
    power = 20*np.log10(np.abs(np.fft.rfft(snd)))
    freq = np.linspace(0, rate/2, len(power))
    # output a tuple of numpy arrays for downstream processing and analysis
    return (freq, power)

# %%
# function to plot the frequency spectrum on a graph with appropriate labels
def plotFreqSpect(freqSpect): 
    plt.title('Frequency Spectrum')
    plt.xlabel('Hz')
    plt.ylabel('dB')
    plt.plot(freqSpect[0], freqSpect[1]) # (freq, power)

# %%
# TO DO: work in 0.05s overlap
def processAudio(snd):
    ''' Function will process an audio sample in 0.25s intervals to output frequency spectrum data. '''
    rate = snd[0]
    step = 1000 # bins in array to sample (~0.25s)
    max_bin = snd[1].shape[0]-1000
    start_bin = 0
    freqSpect = []
    # step over the numpy array and process the audio
    while start_bin < max_bin:
        snippet = snd[1][start_bin:(start_bin+1000)]
        start_bin += step
        freqSpect.append(FFTwithHann(snippet, rate))
    return freqSpect

# %% [markdown]
# ### NOW LET'S PROCESS SOME AUDIO DATA! ^_^

# %%
# process audio wav file into numpy array
#sound4khz = getwavedata('/home/kak9699/Documents/code/RFCx/SoundFiltering/4khz-5m-nt.wav')
sound4khz = getwavedata('C:/Users/kak96_000/Documents/code/scipy-wavelet-test/test.wav')

# plot graph representing the raw sound data file
# makegraph(sound4khz[1], time4khz, sound4khz[0], 'Raw Import File Data')

# %%
# pass in sample sound file at 4kHz
freqSpectData = processAudio(sound4khz)
print freqSpectData[0]
# Out:
# (array([    0.,     4.,     8.,    12.,    16.,    20.,    24.,    28.,
#           32.,    36.,    40.,    44.,    48.,    52.,    56.,    60.,
#           64.,    68.,    72.,    76.,    80.,    84.,    88.,    92.,
#           96.,   100.,   104.,   108.,   112.,   116.,   120.,   124.,
#          128.,   132.,   136.,   140.,   144.,   148.,   152.,   156.,
#          160.,   164.,   168.,   172.,   176.,   180.,   184.,   188.,
#          192.,   196.,   200.,   204.,   208.,   212.,   216.,   220.,
#          224.,   228.,   232.,   236.,   240.,   244.,   248.,   252.,
#          256.,   260.,   264.,   268.,   272.,   276.,   280.,   284.,
#          288.,   292.,   296.,   300.,   304.,   308.,   312.,   316.,
#          320.,   324.,   328.,   332.,   336.,   340.,   344.,   348.,
#          352.,   356.,   360.,   364.,   368.,   372.,   376.,   380.,
#          384.,   388.,   392.,   396.,   400.,   404.,   408.,   412.,
#          416.,   420.,   424.,   428.,   432.,   436.,   440.,   444.,
#          448.,   452.,   456.,   460.,   464.,   468.,   472.,   476.,
#          480.,   484.,   488.,   492.,   496.,   500.,   504.,   508.,
#          512.,   516.,   520.,   524.,   528.,   532.,   536.,   540.,
#          544.,   548.,   552.,   556.,   560.,   564.,   568.,   572.,
#          576.,   580.,   584.,   588.,   592.,   596.,   600.,   604.,
#          608.,   612.,   616.,   620.,   624.,   628.,   632.,   636.,
#          640.,   644.,   648.,   652.,   656.,   660.,   664.,   668.,
#          672.,   676.,   680.,   684.,   688.,   692.,   696.,   700.,
#          704.,   708.,   712.,   716.,   720.,   724.,   728.,   732.,
#          736.,   740.,   744.,   748.,   752.,   756.,   760.,   764.,
#          768.,   772.,   776.,   780.,   784.,   788.,   792.,   796.,
#          800.,   804.,   808.,   812.,   816.,   820.,   824.,   828.,
#          832.,   836.,   840.,   844.,   848.,   852.,   856.,   860.,
#          864.,   868.,   872.,   876.,   880.,   884.,   888.,   892.,
#          896.,   900.,   904.,   908.,   912.,   916.,   920.,   924.,
#          928.,   932.,   936.,   940.,   944.,   948.,   952.,   956.,
#          960.,   964.,   968.,   972.,   976.,   980.,   984.,   988.,
#          992.,   996.,  1000.,  1004.,  1008.,  1012.,  1016.,  1020.,
#         1024.,  1028.,  1032.,  1036.,  1040.,  1044.,  1048.,  1052.,
#         1056.,  1060.,  1064.,  1068.,  1072.,  1076.,  1080.,  1084.,
#         1088.,  1092.,  1096.,  1100.,  1104.,  1108.,  1112.,  1116.,
#         1120.,  1124.,  1128.,  1132.,  1136.,  1140.,  1144.,  1148.,
#         1152.,  1156.,  1160.,  1164.,  1168.,  1172.,  1176.,  1180.,
#         1184.,  1188.,  1192.,  1196.,  1200.,  1204.,  1208.,  1212.,
#         1216.,  1220.,  1224.,  1228.,  1232.,  1236.,  1240.,  1244.,
#         1248.,  1252.,  1256.,  1260.,  1264.,  1268.,  1272.,  1276.,
#         1280.,  1284.,  1288.,  1292.,  1296.,  1300.,  1304.,  1308.,
#         1312.,  1316.,  1320.,  1324.,  1328.,  1332.,  1336.,  1340.,
#         1344.,  1348.,  1352.,  1356.,  1360.,  1364.,  1368.,  1372.,
#         1376.,  1380.,  1384.,  1388.,  1392.,  1396.,  1400.,  1404.,
#         1408.,  1412.,  1416.,  1420.,  1424.,  1428.,  1432.,  1436.,
#         1440.,  1444.,  1448.,  1452.,  1456.,  1460.,  1464.,  1468.,
#         1472.,  1476.,  1480.,  1484.,  1488.,  1492.,  1496.,  1500.,
#         1504.,  1508.,  1512.,  1516.,  1520.,  1524.,  1528.,  1532.,
#         1536.,  1540.,  1544.,  1548.,  1552.,  1556.,  1560.,  1564.,
#         1568.,  1572.,  1576.,  1580.,  1584.,  1588.,  1592.,  1596.,
#         1600.,  1604.,  1608.,  1612.,  1616.,  1620.,  1624.,  1628.,
#         1632.,  1636.,  1640.,  1644.,  1648.,  1652.,  1656.,  1660.,
#         1664.,  1668.,  1672.,  1676.,  1680.,  1684.,  1688.,  1692.,
#         1696.,  1700.,  1704.,  1708.,  1712.,  1716.,  1720.,  1724.,
#         1728.,  1732.,  1736.,  1740.,  1744.,  1748.,  1752.,  1756.,
#         1760.,  1764.,  1768.,  1772.,  1776.,  1780.,  1784.,  1788.,
#         1792.,  1796.,  1800.,  1804.,  1808.,  1812.,  1816.,  1820.,
#         1824.,  1828.,  1832.,  1836.,  1840.,  1844.,  1848.,  1852.,
#         1856.,  1860.,  1864.,  1868.,  1872.,  1876.,  1880.,  1884.,
#         1888.,  1892.,  1896.,  1900.,  1904.,  1908.,  1912.,  1916.,
#         1920.,  1924.,  1928.,  1932.,  1936.,  1940.,  1944.,  1948.,
#         1952.,  1956.,  1960.,  1964.,  1968.,  1972.,  1976.,  1980.,
#         1984.,  1988.,  1992.,  1996.,  2000.]), array([ 56.12380389,  50.1704518 ,  22.78064849,  21.06662178,
#         11.60332871,   9.33305204,  19.19632936,  17.64241233,
#         10.65818212,  14.925931  ,  25.86400862,  27.04989361,
#         26.32945525,  11.73220783,  22.75696158,  25.93637601,
#         34.14700807,  30.6189241 ,  24.79653608,  34.70654043,
#         36.1349512 ,  37.79553344,  40.48830059,  33.75428515,
#         39.11916489,  42.76155637,  43.6926413 ,  42.61281128,
#         47.02086705,  46.04737218,  36.10785422,  45.23712274,
#         41.21383346,  43.88032757,  28.71902757,  48.79946238,
#         48.20253628,  45.79602208,  48.67366271,  50.9001625 ,
#         53.42397952,  52.44504557,  48.86011924,  43.45661973,
#         44.50975993,  51.44199013,  48.01125288,  52.17426829,
#         42.53850911,  44.56554082,  53.31208737,  54.56539849,
#         47.47691485,  53.6857343 ,  55.69553478,  50.40768294,
#         54.44050196,  44.54735993,  47.32770154,  47.50320417,
#         50.59759324,  41.24079562,  52.02703116,  42.84038355,
#         51.41829555,  47.92646107,  51.83295506,  56.69210917,
#         52.66264314,  49.98720172,  49.2144599 ,  58.67628153,
#         50.42239069,  46.69342129,  53.7949211 ,  59.00869377,
#         55.17167176,  56.79952903,  54.27381507,  53.6184763 ,
#         37.6530882 ,  48.55893691,  43.10742381,  50.07319584,
#         53.01809899,  58.59669751,  59.94448   ,  57.55216008,
#         53.24260432,  56.4182045 ,  57.69725884,  51.98888327,
#         44.70871354,  49.06238179,  52.30900155,  58.60984272,
#         55.11270722,  50.95620042,  49.37116319,  45.89123512,
#         54.02628629,  53.31482413,  48.00212342,  48.03795331,
#         49.72734222,  44.48595865,  45.64803599,  48.65730272,
#         52.21219661,  49.28384962,  36.80867177,  41.66738772,
#         40.40253617,  36.13833073,  50.75132325,  49.11840416,
#         35.9105751 ,  43.29367654,  49.48303656,  55.5944459 ,
#         54.19509579,  46.08706257,  50.58034208,  50.7107712 ,
#         50.74968033,  52.32834414,  51.30574255,  52.90807609,
#         54.80889113,  46.94838331,  42.70457193,  44.77243104,
#         50.38184718,  47.35503226,  47.63605066,  47.65620161,
#         47.6301787 ,  50.35722977,  52.99857545,  50.53596017,
#         44.23065645,  46.54655814,  38.03203084,  48.10006631,
#         51.55908876,  54.29507424,  59.27744178,  57.72685788,
#         57.6226476 ,  62.74897176,  48.46049123,  66.77537063,
#         67.98205256,  61.28246449,  52.80094095,  50.5101396 ,
#         56.01430794,  58.89164218,  54.30495087,  51.00233273,
#         53.41197634,  59.9981783 ,  58.86612733,  48.43109935,
#         53.59702839,  55.3486765 ,  51.51640175,  54.55470949,
#         57.51320912,  56.27256697,  51.68728251,  56.43733799,
#         61.75153872,  61.12865461,  52.02640422,  56.33727367,
#         59.21983007,  60.60764973,  61.68866625,  59.04538351,
#         54.52141651,  53.21213243,  45.95746532,  41.36985488,
#         56.34391093,  58.94752384,  53.61958542,  46.84617024,
#         46.54144638,  40.14246566,  51.77767918,  55.33341126,
#         56.30624989,  55.17076515,  48.38212594,  49.60370818,
#         47.9750319 ,  51.16473315,  58.25460541,  56.70181795,
#         53.20012045,  59.92578878,  48.02865023,  47.35451932,
#         49.90719944,  63.33847516,  63.52062358,  64.13642184,
#         65.51579576,  63.88027831,  53.88340695,  48.33078224,
#         62.70931457,  60.08262809,  38.75521826,  60.28914445,
#         65.1926339 ,  61.72625577,  56.56613809,  30.94917331,
#         46.23669051,  49.50672306,  51.37771191,  51.3951528 ,
#         51.48613073,  52.69935244,  44.51034669,  50.33258682,
#         58.48850095,  53.72393485,  57.67712844,  59.20337791,
#         52.75110573,  63.84651503,  62.37171741,  55.17834636,
#         53.09787293,  47.75346073,  55.98918642,  50.80033611,
#         52.93428784,  54.1711643 ,  55.32445562,  49.47765196,
#         52.56774146,  54.61438532,  50.41265267,  49.54515794,
#         55.16749185,  52.30258723,  59.74219143,  60.38636569,
#         57.68317889,  58.03931428,  60.75034667,  62.64747747,
#         52.74329437,  51.48632748,  58.06581092,  58.14518497,
#         43.17868135,  56.9854401 ,  57.34307579,  62.07554311,
#         59.01047717,  57.52464126,  61.79567578,  58.34829786,
#         57.67732749,  59.42051005,  57.03354919,  59.91805209,
#         60.5173914 ,  57.48793493,  42.69789739,  55.08361059,
#         64.81475608,  64.83280176,  60.61498054,  60.45036914,
#         61.94921816,  34.30761002,  66.7969047 ,  67.24012085,
#         62.56185767,  57.99346007,  53.77014953,  43.0461121 ,
#         46.24730832,  55.15434932,  53.81989554,  51.5192382 ,
#         47.9963516 ,  36.04836877,  46.73273725,  46.20981391,
#         41.74338299,  47.68963104,  52.10631249,  54.39760456,
#         52.1530386 ,  42.04768115,  41.50081089,  51.91118926,
#         49.9784209 ,  43.22893488,  40.46239687,  41.39299259,
#         50.86975583,  52.57777261,  51.3343197 ,  42.36378644,
#         29.59652421,  29.82930205,  42.82601418,  46.3914671 ,
#         45.17098456,  41.91546005,  37.30657352,  41.83905286,
#         47.79711228,  44.3620082 ,  41.61856075,  31.50560039,
#         44.21556435,  41.31266438,  38.53384929,  47.60502802,
#         50.10240188,  43.00926352,  39.55743518,  45.20114537,
#         41.18092191,  44.52018807,  51.47433986,  50.62215196,
#         46.45623865,  49.9563362 ,  44.91076778,  41.99123102,
#         44.9518704 ,  45.0104541 ,  42.63860428,  36.09603727,
#         45.60202847,  47.04006884,  35.45117348,  43.85727228,
#         27.99147493,  44.50700682,  37.06326619,  42.79579973,
#         38.89951419,  36.34243419,  45.3996945 ,  48.44038065,
#         42.12249694,  35.23416201,  33.72221464,  44.60861184,
#         45.64856467,  33.98113936,  43.70770507,  45.2247403 ,
#         42.41880811,  43.83883962,  48.76412406,  46.50907302,
#          5.61020636,  36.43107225,  38.7452771 ,  35.73787287,
#         40.64968237,  46.38172976,  39.67962242,  46.03974665,
#         48.43941813,  48.02932804,  40.17607312,  38.83501561,
#         32.54641857,  35.35174336,  35.88294152,  37.72103032,
#         45.24802284,  46.28681298,  35.58031729,  39.9550155 ,
#         32.55359692,  40.99190036,  37.5271816 ,  38.66965841,
#         43.51103654,  40.64114214,  44.05537516,  52.82476815,
#         53.88025501,  52.38330011,  45.5480391 ,  46.65820216,
#         48.30125359,  43.31869808,  41.12194379,  46.06830516,
#         46.34101748,  40.33982569,  38.77440908,  28.4916622 ,
#         48.74537061,  45.37738335,  43.25668492,  40.973239  ,
#         46.1246657 ,  42.06466688,  40.6062366 ,  40.14060887,
#         24.89470838,  35.73097607,  38.25959799,  34.14122645,
#         30.02173754,  32.46517377,  34.41698488,  37.82937304,
#         48.23085586,  46.52014945,  40.44564577,  28.77177836,
#         22.34476643,  31.86101989,  37.9724569 ,  41.19461197,
#         42.21376469,  40.91615502,  46.05103442,  48.69287561,
#         44.5162544 ,  39.43353686,  38.87872373,  43.99173733,
#         39.80926627,  39.27657413,  37.36857564,  39.68600737,
#         36.44508899,  24.40384281,  27.66494331,  37.46712454,
#         36.01071612,  36.11610704,  41.82297581,  40.61749536,
#         33.6242394 ,  41.10172815,  47.46547254,  47.71525668,
#         46.88759043,  43.59479533,  32.8865497 ,  33.94385406,
#         44.25328711,  44.21932586,  43.38367433,  41.8861509 ,
#         40.82909762,  34.33226356,  21.09119107,  40.15942819,
#         41.44823256,  40.34695671,  43.31317983,  40.0745815 ,
#         37.70678206,  40.24173691,  37.86557316,  37.06943872,
#         35.7683816 ,  41.24991318,  42.7745146 ,  37.54405946,
#         36.85876297,  34.4118436 ,  40.33839157,  40.30278676,
#         27.05016796,  38.59863063,  37.01692925,  35.54688975,
#         29.62125849,  34.51312294,  37.68002262,  35.51947048,
#         31.80437379,  36.50032793,  27.93616006,  29.85512279,
#         27.99300936,  25.94101066,  34.85459787,  37.78830185,  36.3578288 ]))

# %%
# plot the frequency spectrum graph for the first snippet
plotFreqSpect(freqSpectData[45])
